# %%
import json

import pandas as pd
import spacy

# %%
enron_df = pd.read_pickle('enron_students.pkl')
enron_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 517401 entries, 0 to 517400
# Data columns (total 11 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Date            517401 non-null  object
#  1   From            517401 non-null  object
#  2   To              495554 non-null  object
#  3   X-To            517372 non-null  object
#  4   X-From          517372 non-null  object
#  5   X-cc            517372 non-null  object
#  6   X-bcc           517372 non-null  object
#  7   Subject         517401 non-null  object
#  8   email_body      517401 non-null  object
#  9   verdict         517401 non-null  object
#  10  violated_rules  517401 non-null  object
# dtypes: object(11)
# memory usage: 43.4+ MB

# %%
# constans for run

SHOULD_RUN_ON_SAMPLE = False # Allow quick run for testing purposes todo maor: change to False
SAMPLE_SIZE = 5000
RANDOM_STATE = 3
MAX_DOC_SIZE_FOR_SPACY = 2000

# %%
# pre process
def remove_attachment_text(text):
    keywords = [
        'This is a multi-part message in MIME format',
        'Content-Disposition: attachment;',
        'Content-Type: multipart/mixed;'
    ]
    
    for keyword in keywords:
        index = text.find(keyword)
        if index != -1:
            return text[:index]  # Return the text up to the found keyword
    return text  # Return the original text if no keywords are found
    

def parse_contacts(data):
    # count the number of '~' in the data to check if its notes
    count = data.count('~')
    if count < 30:
        return data

    # Normalize the data by removing line continuation characters
    data = data.replace("=\n", "")  # Assumes `=` at the end of the line followed by a newline

    # Split the data into individual records on '#'
    records = data.split('#')

    # Initialize a list to store parsed contacts
    contacts = []

    # Iterate through each record
    for record in records:
        # Split the record into fields using '~'
        fields = record.split('~')

        # TODO: need to check relevant fields
        if len(fields) > 21:  # Check to ensure it's a valid record
            contact = {
                'first_name': fields[1].strip(),
                'last_name': fields[3].strip(),
                'phone_numbers': fields[11:14],
                'position': fields[15].strip(),
                'company': fields[18].strip(),
                'email': fields[21].strip() if len(fields) > 21 else None  # Safeguard for missing email
            }
            contacts.append(contact)
            # print('contact:', contact)

    if not contacts:
        return ' '
    return json.dumps(contacts)


def remove_substring(text, start, end):
    # Regex pattern to match a substring that starts with 'X-d' and ends with 'subject'
    pattern = rf'{start}.*?{end}'
    # Replace the matching substring with an empty string
    cleaned_text = re.sub(pattern, '', text, flags=re.DOTALL)
    return cleaned_text

# remove forward text
def remove_forward_text(text: str):
    text = text.replace('FW:', '')
    text = text.replace('RE:', '')
    text = remove_substring(text, '----------- Forwarded', 'Subject')
    text = text.replace('-', '')
    text = text.replace('\\n', ' ')
    text = text.replace(':', ' ')
    return text
    

def data_cleaning(enron_df):
    # enron_df['email_text'] = enron_df['email_text'].apply(remove_attachment_text)
    # print('removed attachments')

    # remove attachment file if remove_attachment_text is true
    # Remove rows where remove_attachment_text returns True
    enron_df['email_text'] = enron_df['email_text'].apply(remove_attachment_text)

    # print('removed attachments')

    enron_df['email_text'] = enron_df['email_text'].apply(remove_forward_text)
    print('removed foward text')

    enron_df['email_text'] = enron_df['email_text'].apply(parse_contacts)
    print('parsed contacts')

    enron_df['email_text'] = enron_df['email_text'].fillna(' ')
    
enron_df['email_text'] = enron_df['Subject'] + ' ' + enron_df['email_body']
data_cleaning(enron_df)
# Out:
# removed foward text
# parsed contacts

# %%
violating_rule_2_df = enron_df[enron_df['violated_rules'].str.contains('2.', na=False)]
non_violating_rule_2_df = enron_df[enron_df['violated_rules'].str.contains('2.', na=False) == False]


nlp = spacy.load('en_core_web_sm')
nlp.max_length = 1500000

def print_lables(email_body):
    doc = nlp(email_body)
    print(f'Email body: {email_body} | Entities: {[(ent.text, ent.label_) for ent in doc.ents]}')

counter = 0
truncated = 0
def get_entities(document):
    global counter
    global truncated
    counter+= 1
    if counter % 200 == 0:
        print(f'Processed {counter} documents')
    try:
        doc_len = len(document)
        if doc_len > MAX_DOC_SIZE_FOR_SPACY:
            document = document[:MAX_DOC_SIZE_FOR_SPACY]
            truncated+= 1
        doc = nlp(document)
        return [(ent.text, ent.label_) for ent in doc.ents]

    except ValueError as e :
        print(f'Error in document. Error: {e}')
        return []

if SHOULD_RUN_ON_SAMPLE:
    test_df = violating_rule_2_df.sample(SAMPLE_SIZE, random_state = RANDOM_STATE).copy()
else:
    test_df = violating_rule_2_df.copy()
    
print(f"I've copied the DF of size: {test_df.shape}")
test_df.head()
test_df['entities'] = test_df['email_text'].apply(get_entities)
print(f'Truncated {truncated} documents')
test_df.head(200)
# Out:
# I've copied the DF of size: (34893, 12)
# Processed 200 documents
# Processed 400 documents
# Processed 600 documents
# Processed 800 documents
# Processed 1000 documents
# Processed 1200 documents
# Processed 1400 documents
# Processed 1600 documents
# Processed 1800 documents
# Processed 2000 documents
# Processed 2200 documents
# Processed 2400 documents
# Processed 2600 documents
# Processed 2800 documents
# Processed 3000 documents
# Processed 3200 documents
# Processed 3400 documents
# Processed 3600 documents
# Processed 3800 documents
# Processed 4000 documents
# Processed 4200 documents
# Processed 4400 documents
# Processed 4600 documents
# Processed 4800 documents
# Processed 5000 documents
# Processed 5200 documents
# Processed 5400 documents
# Processed 5600 documents
# Processed 5800 documents
# Processed 6000 documents
# Processed 6200 documents
# Processed 6400 documents
# Processed 6600 documents
# Processed 6800 documents
# Processed 7000 documents
# Processed 7200 documents
# Processed 7400 documents
# Processed 7600 documents
# Processed 7800 documents
# Processed 8000 documents
# Processed 8200 documents
# Processed 8400 documents
# Processed 8600 documents
# Processed 8800 documents
# Processed 9000 documents
# Processed 9200 documents
# Processed 9400 documents
# Processed 9600 documents
# Processed 9800 documents
# Processed 10000 documents
# Processed 10200 documents
# Processed 10400 documents
# Processed 10600 documents
# Processed 10800 documents
# Processed 11000 documents
# Processed 11200 documents
# Processed 11400 documents
# Processed 11600 documents
# Processed 11800 documents
# Processed 12000 documents
# Processed 12200 documents
# Processed 12400 documents
# Processed 12600 documents
# Processed 12800 documents
# Processed 13000 documents
# Processed 13200 documents
# Processed 13400 documents
# Processed 13600 documents
# Processed 13800 documents
# Processed 14000 documents
# Processed 14200 documents
# Processed 14400 documents
# Processed 14600 documents
# Processed 14800 documents
# Processed 15000 documents
# Processed 15200 documents
# Processed 15400 documents
# Processed 15600 documents
# Processed 15800 documents
# Processed 16000 documents
# Processed 16200 documents
# Processed 16400 documents
# Processed 16600 documents
# Processed 16800 documents
# Processed 17000 documents
# Processed 17200 documents
# Processed 17400 documents
# Processed 17600 documents
# Processed 17800 documents
# Processed 18000 documents
# Processed 18200 documents
# Processed 18400 documents
# Processed 18600 documents
# Processed 18800 documents
# Processed 19000 documents
# Processed 19200 documents
# Processed 19400 documents
# Processed 19600 documents
# Processed 19800 documents
# Processed 20000 documents
# Processed 20200 documents
# Processed 20400 documents
# Processed 20600 documents
# Processed 20800 documents
# Processed 21000 documents
# Processed 21200 documents
# Processed 21400 documents
# Processed 21600 documents
# Processed 21800 documents
# Processed 22000 documents
# Processed 22200 documents
# Processed 22400 documents
# Processed 22600 documents
# Processed 22800 documents
# Processed 23000 documents
# Processed 23200 documents
# Processed 23400 documents
# Processed 23600 documents
# Processed 23800 documents
# Processed 24000 documents
# Processed 24200 documents
# Processed 24400 documents
# Processed 24600 documents
# Processed 24800 documents
# Processed 25000 documents
# Processed 25200 documents
# Processed 25400 documents
# Processed 25600 documents
# Processed 25800 documents
# Processed 26000 documents
# Processed 26200 documents
# Processed 26400 documents
# Processed 26600 documents
# Processed 26800 documents
# Processed 27000 documents
# Processed 27200 documents
# Processed 27400 documents
# Processed 27600 documents
# Processed 27800 documents
# Processed 28000 documents
# Processed 28200 documents
# Processed 28400 documents
# Processed 28600 documents
# Processed 28800 documents
# Processed 29000 documents
# Processed 29200 documents
# Processed 29400 documents
# Processed 29600 documents
# Processed 29800 documents
# Processed 30000 documents
# Processed 30200 documents
# Processed 30400 documents
# Processed 30600 documents
# Processed 30800 documents
# Processed 31000 documents
# Processed 31200 documents
# Processed 31400 documents
# Processed 31600 documents
# Processed 31800 documents
# Processed 32000 documents
# Processed 32200 documents
# Processed 32400 documents
# Processed 32600 documents
# Processed 32800 documents
# Processed 33000 documents
# Processed 33200 documents
# Processed 33400 documents
# Processed 33600 documents
# Processed 33800 documents
# Processed 34000 documents
# Processed 34200 documents
# Processed 34400 documents
# Processed 34600 documents
# Processed 34800 documents
# Truncated 14435 documents
#                                        Date                     From  \
# 8     Tue, 17 Oct 2000 02:26:00 -0700 (PDT)  phillip.allen@enron.com
# 9     Mon, 16 Oct 2000 06:44:00 -0700 (PDT)  phillip.allen@enron.com
# 10    Mon, 16 Oct 2000 06:42:00 -0700 (PDT)  phillip.allen@enron.com
# 41    Tue, 19 Sep 2000 09:35:00 -0700 (PDT)  phillip.allen@enron.com
# 51    Mon, 11 Sep 2000 09:57:00 -0700 (PDT)  phillip.allen@enron.com
# ...                                     ...                      ...
# 2239  Tue, 14 Aug 2001 14:43:26 -0700 (PDT)       k..allen@enron.com
# 2240  Wed, 15 Aug 2001 07:26:01 -0700 (PDT)       k..allen@enron.com
# 2277  Mon, 10 Sep 2001 06:56:07 -0700 (PDT)       k..allen@enron.com
# 2281  Mon, 10 Sep 2001 11:55:36 -0700 (PDT)       k..allen@enron.com
# 2287  Thu, 13 Sep 2001 07:50:13 -0700 (PDT)       k..allen@enron.com
#
#                               To  \
# 8           mark.scott@enron.com
# 9                zimam@enron.com
# 10    buck.buckner@honeywell.com
# 41          pallen70@hotmail.com
# 51         keith.holst@enron.com
# ...                          ...
# 2239           tec@editingco.com
# 2240                rickm@wt.net
# 2277  mery.l.brown@accenture.com
# 2281    yevgeny.frolov@enron.com
# 2287         jsmith@austintx.com
#
#                                                    X-To  \
# 8                                            Mark Scott
# 9                                       zimam@enron.com
# 10    "Buckner, Buck" <buck.buckner@honeywell.com> @...
# 41                                 pallen70@hotmail.com
# 51                                          Keith Holst
# ...                                                 ...
# 2239                                'tec@editingco.com'
# 2240                                     'rickm@wt.net'
# 2277  'mery.l.brown@accenture.com@ENRON' <IMCEANOTES...
# 2281  Frolov, Yevgeny </O=ENRON/OU=NA/CN=RECIPIENTS/...
# 2287  '"Jeff Smith" <jsmith@austintx.com>@ENRON' <IM...
#
#                                                  X-From  \
# 8                                       Phillip K Allen
# 9                                       Phillip K Allen
# 10                                      Phillip K Allen
# 41                                      Phillip K Allen
# 51                                      Phillip K Allen
# ...                                                 ...
# 2239  Allen, Phillip K. </O=ENRON/OU=NA/CN=RECIPIENT...
# 2240  Allen, Phillip K. </O=ENRON/OU=NA/CN=RECIPIENT...
# 2277  Allen, Phillip K. </O=ENRON/OU=NA/CN=RECIPIENT...
# 2281  Allen, Phillip K. </O=ENRON/OU=NA/CN=RECIPIENT...
# 2287  Allen, Phillip K. </O=ENRON/OU=NA/CN=RECIPIENT...
#
#                         X-cc X-bcc  \
# 8
# 9
# 10
# 41
# 51
# ...                      ...   ...
# 2239  'pallen70@hotmail.com'
# 2240
# 2277
# 2281
# 2287
#
#                                                 Subject  \
# 8                        Re: High Speed Internet Access
# 9     FW: fixed forward or other Collar floor gas pr...
# 10    Re: FW: fixed forward or other Collar floor ga...
# 41                  Westgate Proforma-Phillip Allen.xls
# 51                  Westgate Proforma-Phillip Allen.xls
# ...                                                 ...
# 2239
# 2240                                                FW:
# 2277                     RE: Simulation Common Mistakes
# 2281  RE: Outing Event on Ultra Sailing Yacht set up...
# 2287                                   RE: Leander etc.
#
#                                              email_body verdict  \
# 8     1. login:  pallen pw: ke9davis\n\n I don't thi...   BLOCK
# 9     ---------------------- Forwarded by Phillip K ...   BLOCK
# 10    Mr. Buckner,\n\n For delivered gas behind San ...   BLOCK
# 41    ---------------------- Forwarded by Phillip K ...   BLOCK
# 51    ---------------------- Forwarded by Phillip K ...   BLOCK
# ...                                                 ...     ...
# 2239  Richard,\n\nHere is the power point presentati...   BLOCK
# 2240  \n\n -----Original Message-----\nFrom: \tAllen...   BLOCK
# 2277  Can you send me a schedule of meetings?  Is th...   BLOCK
# 2281  Yevgeny,\n\nCan you send me a schedule of meet...   BLOCK
# 2287   Jeff,\n\nThe attorney's are done with the doc...   BLOCK
#
#      violated_rules                                         email_text  \
# 8               2.3  Re  High Speed Internet Access 1. login   pall...
# 9               2.1   fixed forward or other Collar floor gas price...
# 10          1.3,2.1  Re   fixed forward or other Collar floor gas p...
# 41      1.3,2.1,2.3  Westgate ProformaPhillip Allen.xls   Westgate ...
# 51              2.1  Westgate ProformaPhillip Allen.xls   Westgate ...
# ...             ...                                                ...
# 2239        1.3,2.3   Richard,\n\nHere is the power point presentat...
# 2240        1.3,2.3   \n\n Original Message\nFrom  \tAllen, Phillip...
# 2277        1.3,2.2   Simulation Common Mistakes Can you send me a ...
# 2281            2.3   Outing Event on Ultra Sailing Yacht set up fo...
# 2287        1.3,2.3   Leander etc.  Jeff,\n\nThe attorney's are don...
#
#                                                entities
# 8     [(ISP \n\n  2, ORG), (IP, ORG), (IP, ORG), (25...
# 9     [(Phillip, PERSON), (Microturbine, PERSON), (H...
# 10    [(Buckner, PERSON), (San Diego, GPE), (Enron E...
# 41    [(Westgate ProformaPhillip Allen.xls, PERSON),...
# 51    [(Westgate ProformaPhillip Allen.xls, PERSON),...
# ...                                                 ...
# 2239  [(Richard, PERSON), (tomorrow, DATE), (8 AM, T...
# 2240  [(Phillip K.  \nSent, PERSON), (Tuesday, DATE)...
# 2277  [(today, DATE), (Phillip, PERSON), (IMCEANOTES...
# 2281  [(Ultra Sailing Yacht, ORG), (Enron/Accenture\...
# 2287  [(Jeff, PERSON), (Pauline, PERSON), (Columbus,...
#
# [200 rows x 13 columns]

# %%
test_df.head(200)

QUIDS = ['ORG', 'GPE', 'LOW', 'FAC', 'LOC']
SENSITIVE = ['MONEY', 'PERCENT', 'NORP', 'PRODUCT', 'EVENT']
POTENTIALLY_SENSITIVE = ['DATE', 'TIME', 'QUANTITY', 'ORDINAL', 'CARDINAL', 'PERSON']
unique_entities = set()

for entities in test_df['entities']:
    for ent in entities:
        unique_entities.add(ent[1])
        
test_df['sensitive'] = test_df['entities'].apply(lambda x: [(ent[0], ent[1]) for ent in x if ent[1] in SENSITIVE])
test_df['quids'] = test_df['entities'].apply(lambda x: [(ent[0], ent[1]) for ent in x if ent[1] in QUIDS])
test_df['potentially_sensitive'] = test_df['entities'].apply(lambda x: [(ent[0], ent[1]) for ent in x if ent[1] in POTENTIALLY_SENSITIVE])

test_df.head(200)
# Out:
#                                        Date                     From  \
# 8     Tue, 17 Oct 2000 02:26:00 -0700 (PDT)  phillip.allen@enron.com
# 9     Mon, 16 Oct 2000 06:44:00 -0700 (PDT)  phillip.allen@enron.com
# 10    Mon, 16 Oct 2000 06:42:00 -0700 (PDT)  phillip.allen@enron.com
# 41    Tue, 19 Sep 2000 09:35:00 -0700 (PDT)  phillip.allen@enron.com
# 51    Mon, 11 Sep 2000 09:57:00 -0700 (PDT)  phillip.allen@enron.com
# ...                                     ...                      ...
# 2239  Tue, 14 Aug 2001 14:43:26 -0700 (PDT)       k..allen@enron.com
# 2240  Wed, 15 Aug 2001 07:26:01 -0700 (PDT)       k..allen@enron.com
# 2277  Mon, 10 Sep 2001 06:56:07 -0700 (PDT)       k..allen@enron.com
# 2281  Mon, 10 Sep 2001 11:55:36 -0700 (PDT)       k..allen@enron.com
# 2287  Thu, 13 Sep 2001 07:50:13 -0700 (PDT)       k..allen@enron.com
#
#                               To  \
# 8           mark.scott@enron.com
# 9                zimam@enron.com
# 10    buck.buckner@honeywell.com
# 41          pallen70@hotmail.com
# 51         keith.holst@enron.com
# ...                          ...
# 2239           tec@editingco.com
# 2240                rickm@wt.net
# 2277  mery.l.brown@accenture.com
# 2281    yevgeny.frolov@enron.com
# 2287         jsmith@austintx.com
#
#                                                    X-To  \
# 8                                            Mark Scott
# 9                                       zimam@enron.com
# 10    "Buckner, Buck" <buck.buckner@honeywell.com> @...
# 41                                 pallen70@hotmail.com
# 51                                          Keith Holst
# ...                                                 ...
# 2239                                'tec@editingco.com'
# 2240                                     'rickm@wt.net'
# 2277  'mery.l.brown@accenture.com@ENRON' <IMCEANOTES...
# 2281  Frolov, Yevgeny </O=ENRON/OU=NA/CN=RECIPIENTS/...
# 2287  '"Jeff Smith" <jsmith@austintx.com>@ENRON' <IM...
#
#                                                  X-From  \
# 8                                       Phillip K Allen
# 9                                       Phillip K Allen
# 10                                      Phillip K Allen
# 41                                      Phillip K Allen
# 51                                      Phillip K Allen
# ...                                                 ...
# 2239  Allen, Phillip K. </O=ENRON/OU=NA/CN=RECIPIENT...
# 2240  Allen, Phillip K. </O=ENRON/OU=NA/CN=RECIPIENT...
# 2277  Allen, Phillip K. </O=ENRON/OU=NA/CN=RECIPIENT...
# 2281  Allen, Phillip K. </O=ENRON/OU=NA/CN=RECIPIENT...
# 2287  Allen, Phillip K. </O=ENRON/OU=NA/CN=RECIPIENT...
#
#                         X-cc X-bcc  \
# 8
# 9
# 10
# 41
# 51
# ...                      ...   ...
# 2239  'pallen70@hotmail.com'
# 2240
# 2277
# 2281
# 2287
#
#                                                 Subject  \
# 8                        Re: High Speed Internet Access
# 9     FW: fixed forward or other Collar floor gas pr...
# 10    Re: FW: fixed forward or other Collar floor ga...
# 41                  Westgate Proforma-Phillip Allen.xls
# 51                  Westgate Proforma-Phillip Allen.xls
# ...                                                 ...
# 2239
# 2240                                                FW:
# 2277                     RE: Simulation Common Mistakes
# 2281  RE: Outing Event on Ultra Sailing Yacht set up...
# 2287                                   RE: Leander etc.
#
#                                              email_body verdict  \
# 8     1. login:  pallen pw: ke9davis\n\n I don't thi...   BLOCK
# 9     ---------------------- Forwarded by Phillip K ...   BLOCK
# 10    Mr. Buckner,\n\n For delivered gas behind San ...   BLOCK
# 41    ---------------------- Forwarded by Phillip K ...   BLOCK
# 51    ---------------------- Forwarded by Phillip K ...   BLOCK
# ...                                                 ...     ...
# 2239  Richard,\n\nHere is the power point presentati...   BLOCK
# 2240  \n\n -----Original Message-----\nFrom: \tAllen...   BLOCK
# 2277  Can you send me a schedule of meetings?  Is th...   BLOCK
# 2281  Yevgeny,\n\nCan you send me a schedule of meet...   BLOCK
# 2287   Jeff,\n\nThe attorney's are done with the doc...   BLOCK
#
#      violated_rules                                         email_text  \
# 8               2.3  Re  High Speed Internet Access 1. login   pall...
# 9               2.1   fixed forward or other Collar floor gas price...
# 10          1.3,2.1  Re   fixed forward or other Collar floor gas p...
# 41      1.3,2.1,2.3  Westgate ProformaPhillip Allen.xls   Westgate ...
# 51              2.1  Westgate ProformaPhillip Allen.xls   Westgate ...
# ...             ...                                                ...
# 2239        1.3,2.3   Richard,\n\nHere is the power point presentat...
# 2240        1.3,2.3   \n\n Original Message\nFrom  \tAllen, Phillip...
# 2277        1.3,2.2   Simulation Common Mistakes Can you send me a ...
# 2281            2.3   Outing Event on Ultra Sailing Yacht set up fo...
# 2287        1.3,2.3   Leander etc.  Jeff,\n\nThe attorney's are don...
#
#                                                entities  \
# 8     [(ISP \n\n  2, ORG), (IP, ORG), (IP, ORG), (25...
# 9     [(Phillip, PERSON), (Microturbine, PERSON), (H...
# 10    [(Buckner, PERSON), (San Diego, GPE), (Enron E...
# 41    [(Westgate ProformaPhillip Allen.xls, PERSON),...
# 51    [(Westgate ProformaPhillip Allen.xls, PERSON),...
# ...                                                 ...
# 2239  [(Richard, PERSON), (tomorrow, DATE), (8 AM, T...
# 2240  [(Phillip K.  \nSent, PERSON), (Tuesday, DATE)...
# 2277  [(today, DATE), (Phillip, PERSON), (IMCEANOTES...
# 2281  [(Ultra Sailing Yacht, ORG), (Enron/Accenture\...
# 2287  [(Jeff, PERSON), (Pauline, PERSON), (Columbus,...
#
#                                           sensitive  \
# 8                                                []
# 9                               [(Burnertip, NORP)]
# 10                                               []
# 41          [(over 40%, PERCENT), (680,000, MONEY)]
# 51          [(over 40%, PERCENT), (680,000, MONEY)]
# ...                                             ...
# 2239                                             []
# 2240                                             []
# 2277                                             []
# 2281  [(Dutch, NORP), (Reese, NORP), (Solis, NORP)]
# 2287                                             []
#
#                                                   quids  \
# 8     [(ISP \n\n  2, ORG), (IP, ORG), (IP, ORG), (DN...
# 9     [(Honeywell, ORG), (San Diego, GPE), (San Dieg...
# 10    [(San Diego, GPE), (Enron Energy Services, ORG...
# 41    [(Austin, GPE), (the "Smart Growth Corridor, O...
# 51    [(Austin, GPE), (the "Smart Growth Corridor, O...
# ...                                                 ...
# 2239                                                 []
# 2240                                                 []
# 2277  [(Cc \tFrolov, ORG), (tim.orourke@enron.com, O...
# 2281  [(Ultra Sailing Yacht, ORG), (Enron/Accenture\...
# 2287  [(Columbus, GPE), (The Smith Company, ORG), (A...
#
#                                   potentially_sensitive
# 8     [(255.255.255.248, CARDINAL), (151.164.1.8, CA...
# 9     [(Phillip, PERSON), (Microturbine, PERSON), (1...
# 10    [(Buckner, PERSON), (7138537107, DATE), (Phill...
# 41    [(Westgate ProformaPhillip Allen.xls, PERSON),...
# 51    [(Westgate ProformaPhillip Allen.xls, PERSON),...
# ...                                                 ...
# 2239  [(Richard, PERSON), (tomorrow, DATE), (8 AM, T...
# 2240  [(Phillip K.  \nSent, PERSON), (Tuesday, DATE)...
# 2277  [(today, DATE), (Phillip, PERSON), (IMCEANOTES...
# 2281  [(Yevgeny, PERSON), (today, DATE), (this after...
# 2287  [(Jeff, PERSON), (Pauline, PERSON), (Phillip, ...
#
# [200 rows x 16 columns]

# %%
class PII:
    def __init__(self, entity_type, score, text):
        self.entity_type = entity_type
        self.score = score
        self.text = text
        
    def __str__(self):
        return f'(Entity: {self.entity_type} | Score: {self.score} | Text: {self.text})'

# %%
from presidio_analyzer import AnalyzerEngine

analyzer = AnalyzerEngine()

counter = 0
def analyze_pii(email_body_text):
    global counter
    counter+= 1
    if counter % 200 == 0:
        print(f'Processed {counter} documents')
    pii_list = []
    email_body_text = email_body_text[:2000]
    
    try:
        results = analyzer.analyze(text=email_body_text, language='en')
    except Exception as e:
        print(f'Error in document. Error: {e}')
        return []
    
    for result in results:
        pii_text = build_pii_text(email_body_text, result)
        pii = PII(result.entity_type, result.score, pii_text)
        pii_list.append(pii)

    return pii_list


def build_pii_text(email_body_text, result):
    start = result.start
    end = result.end
    pii_text = email_body_text[start:end]
    return pii_text

# %%
new_df = test_df.copy()
new_df['pii'] = new_df['email_text'].apply(lambda x: analyze_pii(x))
# Out:
# Processed 200 documents
# Processed 400 documents
# Processed 600 documents
# Processed 800 documents
# Processed 1000 documents
# Processed 1200 documents
# Processed 1400 documents
# Processed 1600 documents
# Processed 1800 documents
# Processed 2000 documents
# Processed 2200 documents
# Processed 2400 documents
# Processed 2600 documents
# Processed 2800 documents
# Processed 3000 documents
# Processed 3200 documents
# Processed 3400 documents
# Processed 3600 documents
# Processed 3800 documents
# Processed 4000 documents
# Processed 4200 documents
# Processed 4400 documents
# Processed 4600 documents
# Processed 4800 documents
# Processed 5000 documents
# Processed 5200 documents
# Processed 5400 documents
# Processed 5600 documents
# Processed 5800 documents
# Processed 6000 documents
# Processed 6200 documents
# Processed 6400 documents
# Processed 6600 documents
# Processed 6800 documents
# Processed 7000 documents
# Processed 7200 documents
# Processed 7400 documents
# Processed 7600 documents
# Processed 7800 documents
# Processed 8000 documents
# Processed 8200 documents
# Processed 8400 documents
# Processed 8600 documents
# Processed 8800 documents
# Processed 9000 documents
# Processed 9200 documents
# Processed 9400 documents
# Processed 9600 documents
# Processed 9800 documents
# Processed 10000 documents
# Processed 10200 documents
# Processed 10400 documents
# Processed 10600 documents
# Processed 10800 documents
# Processed 11000 documents
# Processed 11200 documents
# Processed 11400 documents
# Processed 11600 documents
# Processed 11800 documents
# Processed 12000 documents
# Processed 12200 documents
# Processed 12400 documents
# Processed 12600 documents
# Processed 12800 documents
# Processed 13000 documents
# Processed 13200 documents
# Processed 13400 documents
# Processed 13600 documents
# Processed 13800 documents
# Processed 14000 documents
# Processed 14200 documents
# Processed 14400 documents
# Processed 14600 documents
# Processed 14800 documents
# Processed 15000 documents
# Processed 15200 documents
# Processed 15400 documents
# Processed 15600 documents
# Processed 15800 documents
# Processed 16000 documents
# Processed 16200 documents
# Processed 16400 documents
# Processed 16600 documents
# Processed 16800 documents
# Processed 17000 documents
# Processed 17200 documents
# Processed 17400 documents
# Processed 17600 documents
# Processed 17800 documents
# Processed 18000 documents
# Processed 18200 documents
# Processed 18400 documents
# Processed 18600 documents
# Processed 18800 documents
# Processed 19000 documents
# Processed 19200 documents
# Processed 19400 documents
# Processed 19600 documents
# Processed 19800 documents
# Processed 20000 documents
# Processed 20200 documents
# Processed 20400 documents
# Processed 20600 documents
# Processed 20800 documents
# Processed 21000 documents
# Processed 21200 documents
# Processed 21400 documents
# Processed 21600 documents
# Processed 21800 documents
# Processed 22000 documents
# Processed 22200 documents
# Processed 22400 documents
# Processed 22600 documents
# Processed 22800 documents
# Processed 23000 documents
# Processed 23200 documents
# Processed 23400 documents
# Processed 23600 documents
# Processed 23800 documents
# Processed 24000 documents
# Processed 24200 documents
# Processed 24400 documents
# Processed 24600 documents
# Processed 24800 documents
# Processed 25000 documents
# Processed 25200 documents
# Processed 25400 documents
# Processed 25600 documents
# Processed 25800 documents
# Processed 26000 documents
# Processed 26200 documents
# Processed 26400 documents
# Processed 26600 documents
# Processed 26800 documents
# Processed 27000 documents
# Processed 27200 documents
# Processed 27400 documents
# Processed 27600 documents
# Processed 27800 documents
# Processed 28000 documents
# Processed 28200 documents
# Processed 28400 documents
# Processed 28600 documents
# Processed 28800 documents
# Processed 29000 documents
# Processed 29200 documents
# Processed 29400 documents
# Processed 29600 documents
# Processed 29800 documents
# Processed 30000 documents
# Processed 30200 documents
# Processed 30400 documents
# Processed 30600 documents
# Processed 30800 documents
# Processed 31000 documents
# Processed 31200 documents
# Processed 31400 documents
# Processed 31600 documents
# Processed 31800 documents
# Processed 32000 documents
# Processed 32200 documents
# Processed 32400 documents
# Processed 32600 documents
# Processed 32800 documents
# Processed 33000 documents
# Processed 33200 documents
# Processed 33400 documents
# Processed 33600 documents
# Processed 33800 documents
# Processed 34000 documents
# Processed 34200 documents
# Processed 34400 documents
# Processed 34600 documents
# Error in document. Error: int too big to convert
# Processed 34800 documents

# %%
new_df.head(200)
# Out:
#                                        Date                     From  \
# 8     Tue, 17 Oct 2000 02:26:00 -0700 (PDT)  phillip.allen@enron.com
# 9     Mon, 16 Oct 2000 06:44:00 -0700 (PDT)  phillip.allen@enron.com
# 10    Mon, 16 Oct 2000 06:42:00 -0700 (PDT)  phillip.allen@enron.com
# 41    Tue, 19 Sep 2000 09:35:00 -0700 (PDT)  phillip.allen@enron.com
# 51    Mon, 11 Sep 2000 09:57:00 -0700 (PDT)  phillip.allen@enron.com
# ...                                     ...                      ...
# 2239  Tue, 14 Aug 2001 14:43:26 -0700 (PDT)       k..allen@enron.com
# 2240  Wed, 15 Aug 2001 07:26:01 -0700 (PDT)       k..allen@enron.com
# 2277  Mon, 10 Sep 2001 06:56:07 -0700 (PDT)       k..allen@enron.com
# 2281  Mon, 10 Sep 2001 11:55:36 -0700 (PDT)       k..allen@enron.com
# 2287  Thu, 13 Sep 2001 07:50:13 -0700 (PDT)       k..allen@enron.com
#
#                               To  \
# 8           mark.scott@enron.com
# 9                zimam@enron.com
# 10    buck.buckner@honeywell.com
# 41          pallen70@hotmail.com
# 51         keith.holst@enron.com
# ...                          ...
# 2239           tec@editingco.com
# 2240                rickm@wt.net
# 2277  mery.l.brown@accenture.com
# 2281    yevgeny.frolov@enron.com
# 2287         jsmith@austintx.com
#
#                                                    X-To  \
# 8                                            Mark Scott
# 9                                       zimam@enron.com
# 10    "Buckner, Buck" <buck.buckner@honeywell.com> @...
# 41                                 pallen70@hotmail.com
# 51                                          Keith Holst
# ...                                                 ...
# 2239                                'tec@editingco.com'
# 2240                                     'rickm@wt.net'
# 2277  'mery.l.brown@accenture.com@ENRON' <IMCEANOTES...
# 2281  Frolov, Yevgeny </O=ENRON/OU=NA/CN=RECIPIENTS/...
# 2287  '"Jeff Smith" <jsmith@austintx.com>@ENRON' <IM...
#
#                                                  X-From  \
# 8                                       Phillip K Allen
# 9                                       Phillip K Allen
# 10                                      Phillip K Allen
# 41                                      Phillip K Allen
# 51                                      Phillip K Allen
# ...                                                 ...
# 2239  Allen, Phillip K. </O=ENRON/OU=NA/CN=RECIPIENT...
# 2240  Allen, Phillip K. </O=ENRON/OU=NA/CN=RECIPIENT...
# 2277  Allen, Phillip K. </O=ENRON/OU=NA/CN=RECIPIENT...
# 2281  Allen, Phillip K. </O=ENRON/OU=NA/CN=RECIPIENT...
# 2287  Allen, Phillip K. </O=ENRON/OU=NA/CN=RECIPIENT...
#
#                         X-cc X-bcc  \
# 8
# 9
# 10
# 41
# 51
# ...                      ...   ...
# 2239  'pallen70@hotmail.com'
# 2240
# 2277
# 2281
# 2287
#
#                                                 Subject  \
# 8                        Re: High Speed Internet Access
# 9     FW: fixed forward or other Collar floor gas pr...
# 10    Re: FW: fixed forward or other Collar floor ga...
# 41                  Westgate Proforma-Phillip Allen.xls
# 51                  Westgate Proforma-Phillip Allen.xls
# ...                                                 ...
# 2239
# 2240                                                FW:
# 2277                     RE: Simulation Common Mistakes
# 2281  RE: Outing Event on Ultra Sailing Yacht set up...
# 2287                                   RE: Leander etc.
#
#                                              email_body verdict  \
# 8     1. login:  pallen pw: ke9davis\n\n I don't thi...   BLOCK
# 9     ---------------------- Forwarded by Phillip K ...   BLOCK
# 10    Mr. Buckner,\n\n For delivered gas behind San ...   BLOCK
# 41    ---------------------- Forwarded by Phillip K ...   BLOCK
# 51    ---------------------- Forwarded by Phillip K ...   BLOCK
# ...                                                 ...     ...
# 2239  Richard,\n\nHere is the power point presentati...   BLOCK
# 2240  \n\n -----Original Message-----\nFrom: \tAllen...   BLOCK
# 2277  Can you send me a schedule of meetings?  Is th...   BLOCK
# 2281  Yevgeny,\n\nCan you send me a schedule of meet...   BLOCK
# 2287   Jeff,\n\nThe attorney's are done with the doc...   BLOCK
#
#      violated_rules                                         email_text  \
# 8               2.3  Re  High Speed Internet Access 1. login   pall...
# 9               2.1   fixed forward or other Collar floor gas price...
# 10          1.3,2.1  Re   fixed forward or other Collar floor gas p...
# 41      1.3,2.1,2.3  Westgate ProformaPhillip Allen.xls   Westgate ...
# 51              2.1  Westgate ProformaPhillip Allen.xls   Westgate ...
# ...             ...                                                ...
# 2239        1.3,2.3   Richard,\n\nHere is the power point presentat...
# 2240        1.3,2.3   \n\n Original Message\nFrom  \tAllen, Phillip...
# 2277        1.3,2.2   Simulation Common Mistakes Can you send me a ...
# 2281            2.3   Outing Event on Ultra Sailing Yacht set up fo...
# 2287        1.3,2.3   Leander etc.  Jeff,\n\nThe attorney's are don...
#
#                                                entities  \
# 8     [(ISP \n\n  2, ORG), (IP, ORG), (IP, ORG), (25...
# 9     [(Phillip, PERSON), (Microturbine, PERSON), (H...
# 10    [(Buckner, PERSON), (San Diego, GPE), (Enron E...
# 41    [(Westgate ProformaPhillip Allen.xls, PERSON),...
# 51    [(Westgate ProformaPhillip Allen.xls, PERSON),...
# ...                                                 ...
# 2239  [(Richard, PERSON), (tomorrow, DATE), (8 AM, T...
# 2240  [(Phillip K.  \nSent, PERSON), (Tuesday, DATE)...
# 2277  [(today, DATE), (Phillip, PERSON), (IMCEANOTES...
# 2281  [(Ultra Sailing Yacht, ORG), (Enron/Accenture\...
# 2287  [(Jeff, PERSON), (Pauline, PERSON), (Columbus,...
#
#                                           sensitive  \
# 8                                                []
# 9                               [(Burnertip, NORP)]
# 10                                               []
# 41          [(over 40%, PERCENT), (680,000, MONEY)]
# 51          [(over 40%, PERCENT), (680,000, MONEY)]
# ...                                             ...
# 2239                                             []
# 2240                                             []
# 2277                                             []
# 2281  [(Dutch, NORP), (Reese, NORP), (Solis, NORP)]
# 2287                                             []
#
#                                                   quids  \
# 8     [(ISP \n\n  2, ORG), (IP, ORG), (IP, ORG), (DN...
# 9     [(Honeywell, ORG), (San Diego, GPE), (San Dieg...
# 10    [(San Diego, GPE), (Enron Energy Services, ORG...
# 41    [(Austin, GPE), (the "Smart Growth Corridor, O...
# 51    [(Austin, GPE), (the "Smart Growth Corridor, O...
# ...                                                 ...
# 2239                                                 []
# 2240                                                 []
# 2277  [(Cc \tFrolov, ORG), (tim.orourke@enron.com, O...
# 2281  [(Ultra Sailing Yacht, ORG), (Enron/Accenture\...
# 2287  [(Columbus, GPE), (The Smith Company, ORG), (A...
#
#                                   potentially_sensitive  \
# 8     [(255.255.255.248, CARDINAL), (151.164.1.8, CA...
# 9     [(Phillip, PERSON), (Microturbine, PERSON), (1...
# 10    [(Buckner, PERSON), (7138537107, DATE), (Phill...
# 41    [(Westgate ProformaPhillip Allen.xls, PERSON),...
# 51    [(Westgate ProformaPhillip Allen.xls, PERSON),...
# ...                                                 ...
# 2239  [(Richard, PERSON), (tomorrow, DATE), (8 AM, T...
# 2240  [(Phillip K.  \nSent, PERSON), (Tuesday, DATE)...
# 2277  [(today, DATE), (Phillip, PERSON), (IMCEANOTES...
# 2281  [(Yevgeny, PERSON), (today, DATE), (this after...
# 2287  [(Jeff, PERSON), (Pauline, PERSON), (Phillip, ...
#
#                                                     pii
# 8     [(Entity: IP_ADDRESS | Score: 0.95 | Text: 64....
# 9     [(Entity: PERSON | Score: 0.85 | Text: degen),...
# 10    [(Entity: UK_NHS | Score: 1.0 | Text: 71385371...
# 41    [(Entity: LOCATION | Score: 0.85 | Text: Austi...
# 51    [(Entity: LOCATION | Score: 0.85 | Text: Austi...
# ...                                                 ...
# 2239  [(Entity: UK_NHS | Score: 1.0 | Text: 71346386...
# 2240  [(Entity: EMAIL_ADDRESS | Score: 1.0 | Text: t...
# 2277  [(Entity: EMAIL_ADDRESS | Score: 1.0 | Text: m...
# 2281  [(Entity: EMAIL_ADDRESS | Score: 1.0 | Text: e...
# 2287  [(Entity: EMAIL_ADDRESS | Score: 1.0 | Text: j...
#
# [200 rows x 17 columns]

# %%
unique_entities_presidio = set()
for index, row in new_df.iterrows():
    for pii in row['pii']:
        unique_entities_presidio.add(pii.entity_type)
        
print(unique_entities_presidio)
print(f'Number of unique entities: {len(unique_entities_presidio)}')
# Out:
# {'EMAIL_ADDRESS', 'IP_ADDRESS', 'AU_ACN', 'URL', 'US_ITIN', 'IN_AADHAAR', 'LOCATION', 'UK_NHS', 'AU_TFN', 'US_BANK_NUMBER', 'IN_PAN', 'PERSON', 'DATE_TIME', 'US_DRIVER_LICENSE', 'IN_VEHICLE_REGISTRATION', 'SG_NRIC_FIN', 'AU_MEDICARE', 'US_SSN', 'US_PASSPORT', 'MEDICAL_LICENSE', 'NRP', 'AU_ABN', 'CREDIT_CARD', 'PHONE_NUMBER'}
# Number of unique entities: 24

# %%
import re


def find_all_ssn(text):
    return re.findall(r'\d{3}-\d{2}-\d{4}', text)

def find_all_credit_cards(text):
    return re.findall(r'\d{4}-\d{4}-\d{4}-\d{4}', text) 

def find_all_phone_numbers(text):
    return re.findall(r'\(?\d{3}\)?\s*-\s*\d{3}\s*-\s*\d{4}', text) 

def find_sensitive_words(text):
    return re.findall(r'password|attach|confidential', text.lower())


text = "Wow. my my password is: abc31234 . Go and buy flight tickets with my credit card: 9591-9878-3320-0031. SSN: 123-45-6789. My phone number is (531)-223-7709', '(531) - 223 - 7709' or 531 -223-7709', 713-646-3490 '(531) - 223 - 7709'. I live in New York. I am 25 years old. I was born on 12/12/1996. I am 1.75m tall. attached as a file my password: 20212. attachment"

print(find_all_ssn(text))
print(find_all_credit_cards(text))
print(find_all_phone_numbers(text))
print(find_sensitive_words(text))
# Out:
# ['123-45-6789']
# ['9591-9878-3320-0031']
# ['(531)-223-7709', '(531) - 223 - 7709', '531 -223-7709', '713-646-3490', '(531) - 223 - 7709']
# ['password', 'attach', 'password', 'attach']

# %%
NON_SENSITIVE = ['EMAIL_ADDRESS', 'URL', 'ORG']
SENSITIVE = ['IP_ADDRESS', 'AU_ACN', 'US_ITIN', 'UK_NHS', 'AU_TFN', 'US_BANK_NUMBER', 'IN_PAN', 'US_DRIVER_LICENSE', 'IN_VEHICLE_REGISTRATION', 'SG_NRIC_FIN', 'US_SSN', 'US_PASSPORT', 'MEDICAL_LICENSE', 'PHONE_NUMBER']
QUASI_SENSITIVE = ['NRP', 'LOCATION', 'PERSON', 'DATE_TIME', 'GPE']

def predict_presidio_verdict(row):
    persons_counter = 0
    if row is None:
        return 'Non-sensitive'
    
    email_text = row['email_text']
    if email_text is None:
        return 'Non-sensitive'
    if len(find_sensitive_words(row['email_text'])) > 0 or len(find_all_phone_numbers(email_text)) > 0 or len(
            find_all_credit_cards(email_text)) > 0 or len(find_all_ssn(email_text)) > 0:
        return 'Sensitive'

    if row['pii'] is None:
        return 'Non-sensitive'
    for pii in row['pii']:
        if pii.score < 0.5:
            continue
        if pii.entity_type.startswith('IN_'):
            continue
        if pii.entity_type in NON_SENSITIVE:
            continue
        if pii.entity_type in SENSITIVE:
            return 'Sensitive'
        if pii.entity_type in QUASI_SENSITIVE: # Todo maor - if we have 2 or more QUIDS, we consider it sensitive in 2.3
            if pii.entity_type == 'PERSON':
                persons_counter += 1
                if persons_counter > 2:
                    return 'Sensitive'
            else:
                return 'Sensitive'
            
        else:
            print(f'MA ZE: {ent}')
        
    return 'Non-sensitive'
    

def predict_spacy_verdict(row):
    count_persons = 0
    if len(find_sensitive_words(row['email_text'])) > 0:
        return 'Sensitive'
    if row['quids'] and len(row['quids']) > 0: # Todo maor - if we have 2 or more QUIDS, we consider it sensitive in 2.3
        return 'Sensitive'
    elif row['sensitive'] and len(row['sensitive']) > 0:
        return 'Sensitive'
    elif row['potentially_sensitive'] and len(row['potentially_sensitive']) > 0:
        for ent in row['potentially_sensitive']:
            if ent[1] == 'DATE':
                continue
            elif ent[1] == 'TIME':
                continue
            elif ent[1] == 'QUANTITY':
                continue
            elif ent[1] == 'ORDINAL':
                continue
            elif ent[1] == 'CARDINAL':
                if len(find_all_phone_numbers(ent[0])) > 0 or len(find_all_credit_cards(ent[0])) > 0 or len(find_all_ssn(ent[0])) > 0:
                    return 'Sensitive'
            elif ent[1] == 'PERSON':
                count_persons += 1
                if count_persons > 2:
                    return 'Sensitive'
                continue
        return 'Non-sensitive'
    else:
        return 'Non-sensitive'
    
new_df['spacy_verdict'] = new_df.apply(predict_spacy_verdict, axis=1)
new_df.head(10)
new_df['presidio_verdict'] = new_df.apply(predict_presidio_verdict, axis=1)
spacy_didnt_blocked_but_blocked_in_dataset = new_df[new_df['spacy_verdict'] == 'Non-sensitive']
spacy_didnt_blocked_but_blocked_in_dataset.head(200)

presidio_didnt_blocked_but_blocked_in_dataset = new_df[new_df['presidio_verdict'] == 'Non-sensitive']
presidio_didnt_blocked_but_blocked_in_dataset.head(200)

presidio_accuracy = 100 - (100 * len(presidio_didnt_blocked_but_blocked_in_dataset) / len(new_df))
spacy_accuracy = 100 -(100 * len(spacy_didnt_blocked_but_blocked_in_dataset) / len(new_df))
print(f'Presidio accuracy: {presidio_accuracy}% with {len(presidio_didnt_blocked_but_blocked_in_dataset)} emails left out of {len(new_df)}')
print(f'Spacy accuracy: {spacy_accuracy}% with {len(spacy_didnt_blocked_but_blocked_in_dataset)} emails left out of {len(new_df)}')
# Out:
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# MA ZE: ('Chicago', 'GPE')
# Presidio accuracy: 98.99979938669647% with 349 emails left out of 34893
# Spacy accuracy: 98.94821310864643% with 367 emails left out of 34893

# %%
presidio_didnt_blocked_but_blocked_in_dataset.head(200)
# Out:
#                                          Date  \
# 251      Mon, 7 Feb 2000 08:53:00 -0800 (PST)
# 599     Mon, 23 Oct 2000 08:55:00 -0700 (PDT)
# 849      Mon, 7 Feb 2000 08:53:00 -0800 (PST)
# 1222    Mon, 23 Oct 2000 08:55:00 -0700 (PDT)
# 1665    Mon, 23 Oct 2000 08:55:00 -0700 (PDT)
# ...                                       ...
# 316995   Fri, 1 Jun 2001 00:54:00 -0700 (PDT)
# 323216   Thu, 3 Jan 2002 15:02:46 -0800 (PST)
# 323431   Mon, 4 Feb 2002 12:15:08 -0800 (PST)
# 324390   Thu, 3 Jan 2002 15:02:46 -0800 (PST)
# 332375  Thu, 21 Feb 2002 08:50:57 -0800 (PST)
#
#                                    From  \
# 251             phillip.allen@enron.com
# 599             phillip.allen@enron.com
# 849             phillip.allen@enron.com
# 1222            phillip.allen@enron.com
# 1665            phillip.allen@enron.com
# ...                                 ...
# 316995            lorie.leigh@enron.com
# 323216  danielle.marcinkowski@enron.com
# 323431             gary.bryan@enron.com
# 324390  danielle.marcinkowski@enron.com
# 332375         tammie.schoppe@enron.com
#
#                                                        To  \
# 251                             george.rahal@acnpower.com
# 599                                  jedglick@hotmail.com
# 849                             george.rahal@acnpower.com
# 1222                                 jedglick@hotmail.com
# 1665                                 jedglick@hotmail.com
# ...                                                   ...
# 316995                                 kay.mann@enron.com
# 323216  rudy.acevedo@enron.com, k..allen@enron.com, to...
# 323431                           mary.grif.gray@enron.com
# 324390  rudy.acevedo@enron.com, k..allen@enron.com, to...
# 332375  bill.abler@enron.com, caroline.abramo@enron.co...
#
#                                                      X-To  \
# 251     "George Rahal" <george.rahal@acnpower.com> @ E...
# 599                                  Jedglick@hotmail.com
# 849     "George Rahal" <george.rahal@acnpower.com> @ E...
# 1222                                 Jedglick@hotmail.com
# 1665                                 Jedglick@hotmail.com
# ...                                                   ...
# 316995                                           Kay Mann
# 323216  Acevedo, Rudy </O=ENRON/OU=NA/CN=RECIPIENTS/CN...
# 323431                         'mary.grif.gray@enron.com'
# 324390  Acevedo, Rudy </O=ENRON/OU=NA/CN=RECIPIENTS/CN...
# 332375  Abler, Bill </O=ENRON/OU=NA/CN=RECIPIENTS/CN=W...
#
#                                                    X-From  \
# 251                                       Phillip K Allen
# 599                                       Phillip K Allen
# 849                                       Phillip K Allen
# 1222                                      Phillip K Allen
# 1665                                      Phillip K Allen
# ...                                                   ...
# 316995                                        Lorie Leigh
# 323216  Marcinkowski, Danielle </O=ENRON/OU=NA/CN=RECI...
# 323431  Bryan, Gary </O=ENRON/OU=NA/CN=RECIPIENTS/CN=G...
# 324390  Marcinkowski, Danielle </O=ENRON/OU=NA/CN=RECI...
# 332375  Schoppe, Tammie </O=ENRON/OU=NA/CN=RECIPIENTS/...
#
#                                                      X-cc X-bcc  \
# 251
# 599
# 849
# 1222
# 1665
# ...                                                   ...   ...
# 316995
# 323216
# 323431  Vickers, Frank </O=ENRON/OU=NA/CN=RECIPIENTS/C...
# 324390
# 332375
#
#                                                   Subject  \
# 251                                    Re: W basis quotes
# 599                                                 Enron
# 849                                    Re: W basis quotes
# 1222                                                Enron
# 1665                                                Enron
# ...                                                   ...
# 316995  FPL construction letter agreement - Midway Pha...
# 323216                               Reutes Kobra Changes
# 323431                         TXU Energy Trading Company
# 324390                               Reutes Kobra Changes
# 332375                                       Trading list
#
#                                                email_body verdict  \
# 251     George,\n\n Can you please call my credit desk...   BLOCK
# 599     Jed,\n\n I understand you have been contacted ...   BLOCK
# 849     George,\n\n Can you please call my credit desk...   BLOCK
# 1222    Jed,\n\n I understand you have been contacted ...   BLOCK
# 1665    Jed,\n\n I understand you have been contacted ...   BLOCK
# ...                                                   ...     ...
# 316995  I sent a print out of this letter on letterhea...   BLOCK
# 323216  Market Data has recently made changes to the R...   BLOCK
# 323431  The contacts we previously had listed for TXU ...   BLOCK
# 324390  Market Data has recently made changes to the R...   BLOCK
# 332375   \n\nTammie Schoppe\nUBS Warburg Energy\nAssis...   BLOCK
#
#        violated_rules                                         email_text  \
# 251           1.3,2.1  Re  W basis quotes George,\n\n Can you please ...
# 599           1.3,2.1  Enron Jed,\n\n I understand you have been cont...
# 849           1.3,2.1  Re  W basis quotes George,\n\n Can you please ...
# 1222          1.3,2.1  Enron Jed,\n\n I understand you have been cont...
# 1665          1.3,2.1  Enron Jed,\n\n I understand you have been cont...
# ...               ...                                                ...
# 316995            2.1  FPL construction letter agreement  Midway Phas...
# 323216        1.3,2.1  Reutes Kobra Changes Market Data has recently ...
# 323431            2.1  TXU Energy Trading Company The contacts we pre...
# 324390        1.3,2.1  Reutes Kobra Changes Market Data has recently ...
# 332375    1.3,2.1,2.3  Trading list  \n\nTammie Schoppe\nUBS Warburg ...
#
#                                                  entities sensitive  \
# 251     [(George, PERSON), (7138531803, DATE), (ACN Po...        []
# 599     [(Enron Jed, PERSON), (Enron, ORG), (Phillip A...        []
# 849     [(George, PERSON), (7138531803, DATE), (ACN Po...        []
# 1222    [(Enron Jed, PERSON), (Enron, ORG), (Phillip A...        []
# 1665    [(Enron Jed, PERSON), (Enron, ORG), (Phillip A...        []
# ...                                                   ...       ...
# 316995  [(FPL, ORG), (Midway Phase, ORG), (Ben, PERSON...        []
# 323216  [(Reutes Kobra Changes Market Data, PERSON), (...        []
# 323431  [(TXU Energy Trading Company The, ORG), (TXU, ...        []
# 324390  [(Reutes Kobra Changes Market Data, PERSON), (...        []
# 332375  [(Tammie Schoppe, PERSON), (UBS Warburg Energy...        []
#
#                                                     quids  \
# 251                                    [(ACN Power, ORG)]
# 599                                        [(Enron, ORG)]
# 849                                    [(ACN Power, ORG)]
# 1222                                       [(Enron, ORG)]
# 1665                                       [(Enron, ORG)]
# ...                                                   ...
# 316995                  [(FPL, ORG), (Midway Phase, ORG)]
# 323216                                                 []
# 323431  [(TXU Energy Trading Company The, ORG), (TXU, ...
# 324390                                                 []
# 332375                        [(UBS Warburg Energy, ORG)]
#
#                                     potentially_sensitive  \
# 251     [(George, PERSON), (7138531803, DATE), (Philli...
# 599     [(Enron Jed, PERSON), (Phillip Allen, PERSON),...
# 849     [(George, PERSON), (7138531803, DATE), (Philli...
# 1222    [(Enron Jed, PERSON), (Phillip Allen, PERSON),...
# 1665    [(Enron Jed, PERSON), (Phillip Allen, PERSON),...
# ...                                                   ...
# 316995  [(Ben, PERSON), (Lorie Leigh\nEast Power Gener...
# 323216  [(Reutes Kobra Changes Market Data, PERSON), (...
# 323431  [(three, CARDINAL), (Michael Adams, Risk Contr...
# 324390  [(Reutes Kobra Changes Market Data, PERSON), (...
# 332375  [(Tammie Schoppe, PERSON), (Louise Kitchen, PE...
#
#                                                       pii spacy_verdict  \
# 251     [(Entity: PERSON | Score: 0.85 | Text: George)...     Sensitive
# 599     [(Entity: EMAIL_ADDRESS | Score: 1.0 | Text: p...     Sensitive
# 849     [(Entity: PERSON | Score: 0.85 | Text: George)...     Sensitive
# 1222    [(Entity: EMAIL_ADDRESS | Score: 1.0 | Text: p...     Sensitive
# 1665    [(Entity: EMAIL_ADDRESS | Score: 1.0 | Text: p...     Sensitive
# ...                                                   ...           ...
# 316995  [(Entity: PERSON | Score: 0.85 | Text: Ben), (...     Sensitive
# 323216  [(Entity: PERSON | Score: 0.85 | Text: Reutes ...     Sensitive
# 323431  [(Entity: EMAIL_ADDRESS | Score: 1.0 | Text: m...     Sensitive
# 324390  [(Entity: PERSON | Score: 0.85 | Text: Reutes ...     Sensitive
# 332375  [(Entity: PERSON | Score: 0.85 | Text: Tammie ...     Sensitive
#
#        presidio_verdict
# 251       Non-sensitive
# 599       Non-sensitive
# 849       Non-sensitive
# 1222      Non-sensitive
# 1665      Non-sensitive
# ...                 ...
# 316995    Non-sensitive
# 323216    Non-sensitive
# 323431    Non-sensitive
# 324390    Non-sensitive
# 332375    Non-sensitive
#
# [200 rows x 19 columns]

# %%
spacy_didnt_blocked_but_blocked_in_dataset.head(200)
# Out:
#                                          Date                        From  \
# 443     Fri, 16 Feb 2001 02:15:00 -0800 (PST)     phillip.allen@enron.com
# 448     Thu, 15 Feb 2001 05:33:00 -0800 (PST)     phillip.allen@enron.com
# 1065    Fri, 16 Feb 2001 02:15:00 -0800 (PST)     phillip.allen@enron.com
# 1070    Thu, 15 Feb 2001 05:33:00 -0800 (PST)     phillip.allen@enron.com
# 1827    Thu, 15 Feb 2001 05:33:00 -0800 (PST)     phillip.allen@enron.com
# ...                                       ...                         ...
# 288346  Mon, 25 Mar 2002 08:47:08 -0800 (PST)  audrey.robertson@enron.com
# 291845   Mon, 2 Apr 2001 05:50:00 -0700 (PDT)      phillip.love@enron.com
# 292993   Mon, 2 Apr 2001 05:50:00 -0700 (PDT)      phillip.love@enron.com
# 294358   Mon, 2 Apr 2001 05:50:00 -0700 (PDT)      phillip.love@enron.com
# 295946   Mon, 2 Apr 2001 05:50:00 -0700 (PDT)      phillip.love@enron.com
#
#                                                        To  \
# 443                       andrew_m_ozuna@mail.bankone.com
# 448                                  lodonnell@spbank.com
# 1065                      andrew_m_ozuna@mail.bankone.com
# 1070                                 lodonnell@spbank.com
# 1827                                 lodonnell@spbank.com
# ...                                                   ...
# 288346  kevin.hyatt@enron.com, lindy.donoho@enron.com,...
# 291845                                       oxkd@aol.com
# 292993                                       oxkd@aol.com
# 294358                                       oxkd@aol.com
# 295946                                       oxkd@aol.com
#
#                                                      X-To  \
# 443                       andrew_m_ozuna@mail.bankone.com
# 448                                  lodonnell@spbank.com
# 1065                      andrew_m_ozuna@mail.bankone.com
# 1070                                 lodonnell@spbank.com
# 1827                                 lodonnell@spbank.com
# ...                                                   ...
# 288346  Hyatt, Kevin </O=ENRON/OU=NA/CN=RECIPIENTS/CN=...
# 291845                                       oxkd@aol.com
# 292993                                       oxkd@aol.com
# 294358                                       oxkd@aol.com
# 295946                                       oxkd@aol.com
#
#                                                    X-From  \
# 443                                       Phillip K Allen
# 448                                       Phillip K Allen
# 1065                                      Phillip K Allen
# 1070                                      Phillip K Allen
# 1827                                      Phillip K Allen
# ...                                                   ...
# 288346  Robertson, Audrey </O=ENRON/OU=NA/CN=RECIPIENT...
# 291845                                     Phillip M Love
# 292993                                     Phillip M Love
# 294358                                     Phillip M Love
# 295946                                     Phillip M Love
#
#                                                      X-cc X-bcc  \
# 443
# 448
# 1065
# 1070
# 1827
# ...                                                   ...   ...
# 288346  Winters, Ricki </O=ENRON/OU=NA/CN=RECIPIENTS/C...
# 291845
# 292993
# 294358
# 295946
#
#                                       Subject  \
# 443
# 448
# 1065
# 1070
# 1827
# ...                                       ...
# 288346  Strategy Meeting - TW Commercial Team
# 291845
# 292993
# 294358
# 295946
#
#                                                email_body verdict  \
# 443     Andrew,\n\nHere is an asset statement.  I will...   BLOCK
# 448     Lee,\n\nMy fax number is 713-646-2391.  Please...   BLOCK
# 1065    Andrew,\n\nHere is an asset statement.  I will...   BLOCK
# 1070    Lee,\n\nMy fax number is 713-646-2391.  Please...   BLOCK
# 1827    Lee,\n\nMy fax number is 713-646-2391.  Please...   BLOCK
# ...                                                   ...     ...
# 288346  \nPer discussions in Shelley's introductory me...   BLOCK
# 291845  How are things going?  Good I hope.  Give me a...   BLOCK
# 292993  How are things going?  Good I hope.  Give me a...   BLOCK
# 294358  How are things going?  Good I hope.  Give me a...   BLOCK
# 295946  How are things going?  Good I hope.  Give me a...   BLOCK
#
#        violated_rules                                         email_text  \
# 443               2.3   Andrew,\n\nHere is an asset statement.  I wil...
# 448               2.3   Lee,\n\nMy fax number is 7136462391.  Please ...
# 1065              2.3   Andrew,\n\nHere is an asset statement.  I wil...
# 1070              2.3   Lee,\n\nMy fax number is 7136462391.  Please ...
# 1827              2.3   Lee,\n\nMy fax number is 7136462391.  Please ...
# ...               ...                                                ...
# 288346        1.3,2.3  Strategy Meeting  TW Commercial Team \nPer dis...
# 291845            2.3   How are things going?  Good I hope.  Give me ...
# 292993            2.3   How are things going?  Good I hope.  Give me ...
# 294358            2.3   How are things going?  Good I hope.  Give me ...
# 295946            2.3   How are things going?  Good I hope.  Give me ...
#
#                                                  entities sensitive quids  \
# 443     [(Andrew, PERSON), (98, CARDINAL), (2000, DATE...        []    []
# 448     [(Lee, PERSON), (7136462391, DATE), (Phillip A...        []    []
# 1065    [(Andrew, PERSON), (98, CARDINAL), (2000, DATE...        []    []
# 1070    [(Lee, PERSON), (7136462391, DATE), (Phillip A...        []    []
# 1827    [(Lee, PERSON), (7136462391, DATE), (Phillip A...        []    []
# ...                                                   ...       ...   ...
# 288346  [(Shelley, PERSON), (this morning, TIME), (Thu...        []    []
# 291845                                                 []        []    []
# 292993                                                 []        []    []
# 294358                                                 []        []    []
# 295946                                                 []        []    []
#
#                                     potentially_sensitive  \
# 443     [(Andrew, PERSON), (98, CARDINAL), (2000, DATE...
# 448     [(Lee, PERSON), (7136462391, DATE), (Phillip A...
# 1065    [(Andrew, PERSON), (98, CARDINAL), (2000, DATE...
# 1070    [(Lee, PERSON), (7136462391, DATE), (Phillip A...
# 1827    [(Lee, PERSON), (7136462391, DATE), (Phillip A...
# ...                                                   ...
# 288346  [(Shelley, PERSON), (this morning, TIME), (Thu...
# 291845                                                 []
# 292993                                                 []
# 294358                                                 []
# 295946                                                 []
#
#                                                       pii  spacy_verdict  \
# 443     [(Entity: UK_NHS | Score: 1.0 | Text: 71346386...  Non-sensitive
# 448     [(Entity: EMAIL_ADDRESS | Score: 1.0 | Text: p...  Non-sensitive
# 1065    [(Entity: UK_NHS | Score: 1.0 | Text: 71346386...  Non-sensitive
# 1070    [(Entity: EMAIL_ADDRESS | Score: 1.0 | Text: p...  Non-sensitive
# 1827    [(Entity: EMAIL_ADDRESS | Score: 1.0 | Text: p...  Non-sensitive
# ...                                                   ...            ...
# 288346  [(Entity: EMAIL_ADDRESS | Score: 1.0 | Text: a...  Non-sensitive
# 291845  [(Entity: DATE_TIME | Score: 0.85 | Text: 7138...  Non-sensitive
# 292993  [(Entity: DATE_TIME | Score: 0.85 | Text: 7138...  Non-sensitive
# 294358  [(Entity: DATE_TIME | Score: 0.85 | Text: 7138...  Non-sensitive
# 295946  [(Entity: DATE_TIME | Score: 0.85 | Text: 7138...  Non-sensitive
#
#        presidio_verdict
# 443           Sensitive
# 448           Sensitive
# 1065          Sensitive
# 1070          Sensitive
# 1827          Sensitive
# ...                 ...
# 288346        Sensitive
# 291845        Sensitive
# 292993        Sensitive
# 294358        Sensitive
# 295946        Sensitive
#
# [200 rows x 19 columns]

# %%
# add a column of Sensitive into Block or Not
new_df['presidio_prediction']=new_df['presidio_verdict'].apply(lambda x: 'BLOCK' if x == 'Sensitive' else 'ALLOW')
new_df['spacy_prediction']=new_df['spacy_verdict'].apply(lambda x: 'BLOCK' if x == 'Sensitive' else 'ALLOW')
import sklearn.metrics


presidio_classification_report = sklearn.metrics.classification_report(new_df['verdict'], new_df['presidio_prediction'])
spacy_classification_report = sklearn.metrics.classification_report(new_df['verdict'], new_df['spacy_prediction'])
print('Spacy classification report:\n', spacy_classification_report)
print('\nPresidio classification report:\n', presidio_classification_report)
# Out:
# /Users/maore/Documents/Reichman/Cyber AI/HW/cyber-ai/venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/maore/Documents/Reichman/Cyber AI/HW/cyber-ai/venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/maore/Documents/Reichman/Cyber AI/HW/cyber-ai/venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/maore/Documents/Reichman/Cyber AI/HW/cyber-ai/venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Spacy classification report:
#                precision    recall  f1-score   support
#
#        ALLOW       0.00      0.00      0.00         0
#        BLOCK       1.00      0.99      0.99     34893
#
#     accuracy                           0.99     34893
#    macro avg       0.50      0.49      0.50     34893
# weighted avg       1.00      0.99      0.99     34893
#
#
# Presidio classification report:
#                precision    recall  f1-score   support
#
#        ALLOW       0.00      0.00      0.00         0
#        BLOCK       1.00      0.99      0.99     34893
#
#     accuracy                           0.99     34893
#    macro avg       0.50      0.49      0.50     34893
# weighted avg       1.00      0.99      0.99     34893
# /Users/maore/Documents/Reichman/Cyber AI/HW/cyber-ai/venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/maore/Documents/Reichman/Cyber AI/HW/cyber-ai/venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
